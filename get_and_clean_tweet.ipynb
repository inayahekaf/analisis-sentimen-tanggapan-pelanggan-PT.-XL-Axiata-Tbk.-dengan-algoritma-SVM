# %%
import tweepy
import csv 

ckey = 'yalIxYhkLaDyqnkNU3fjKcNgE'
csecret = 'iNZGwv4F6MU5OEaW4x4retXus04zZ4TJswmN17vAxfOnyVzjVZ'
atoken = '1016593462953558016-JrnZ1eTAaRc86xW7XMiy8daGsOyAHc'
asecret = '3QwfKp1TIO99tsw95hZFNY5rSftpZsCui5TTP7MaJhML2'

auth = tweepy.auth.OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

api = tweepy.API(auth)

tweet_text = []

for tweet in tweepy.Cursor(api.search, q = "myxlcare until:2018-7-12, 
                           -filter:replies -filter:retweets  
                           ",tweet_mode='extended').items():
    tweet_text.append(tweet.full_text)
    
tweet_text
# Out:
# ['Sayang.... kamu kok gada sinyal pas malam hari hingga jam 05.53 ya, padahal udah pilih paket xl prioritas, dulu kamu ga begini tp skrg berubah,  lumayan loh sebulan 150k @myXLCare',
#  'Halo @myXLCare saya ingin aktivasi nomor XL saya yg telah hangus, bagaimana langkah2 nya ?',
#  'Otw ganti provider xl emng paling gak jelas @myXLCare',
#  'Knapa sih XL suka seenaknya motongin pulsa, sampe gk ngeh trnyata ada paket paket gajelas kaya ringtone dan sms apa gt kepotong tiap minggu @myXLCare',
#  'Maksudnya kuota lifestyle apa ya min? @myXLCare https://t.co/9FehKxSdkd',
#  'Halo @myXLCare boleh tahu kenapa sinyal bapuk banget daerah lenteng agung? padahal udah 4G lho, masa browsing google aja ngga bisa?? https://t.co/wCxJB1NtrJ',
#  'Bisa kah request berhentikan iklan yg masuk ke sms dengan menyedot pulsa tiba tiba?\nBisa kah request untuk tidak menerima iklan selamanya?\n@myXLCare @XLAxiata_Tbk @ask_AXIS semoga kaka admin merespon\nMakasih',
#  'Untuk gsm XL, please banget stop-in iklan yg unfaedah dan tetiba nyedot pulsa. Sedih nya, ketika tidak di balas alias di abaikan malah makin sering muncul dan banyak pulsa yg kepotong tibatiba. Tolong@myXLCare \n@XLAxiata_Tbk',
#  'Halo,saya pelanggan XL pascabayar beberapa hari tidak ada koneksi internet,ada tanda seru di sebelah sinyal 4g.tahihan sudah dibayar sebelum jatuh tempo,coba upgrade plan juga sama aja @myXLCare',
#  'Hi @myXLCare apa jaringan di banjarbaru-kalsel lagi down ya?? Kok sejak pagi lola',
#  'Jika kartu sudah hangus apakah data registrasinya akan ter-unreg otomatis ya??? @myXL @myXLCare @ask_AXIS @AXISgsm @Telkomsel',
#  'sinyal XL tiap H+  kga bisa buka internet padahal kuota maaih bnyak @myXLCare',
#  'Kenapa jaringan xl di gowa buruk sekali @myXLCare @XLAxiata_Tbk ada gangguan kah ?',
#  'Di imah we sorangan. https://t.co/7inXglBDof',
#  'Sinyal @myXLCare parah banget.. https://t.co/n1hhdioJQP',
#  'Halo @myXLCare. Nomor saya sudah berkali kali terpotong untuk pemakaian internet padahal sedang tidak menggunakan internet dan saat menggunakan wifi pun juga terpotong pulsa. Kebetulan data di paket internet saya habis dan sedang menunggu perpanjangan otomatis. Tolong solusinya',
#  'Jaringan XL saya kenapa selalu "H" terus ya, kayanya 4G nya kurang stabil ni XL didaerah tambun. @myXLCare',
#  'Sudah dari hari Selasa, sinyal di daerah Bogor tidak asique nih @myXLCare',
#  'Bongkar semua penipuan @myXLCare @myXL @XLAxiata_Tbk .\n\nPaket di curi , pulsa di habisi , masih di bohongi pula.\n\n@kemkominfo @jokowi berani bertindak apa tidak?',
#  'Di depok cmmgs dan margonda juga sama. Bahkan sampai hari ini hilang signal https://t.co/zcHtpjZnJr',
#  'Selamat sore, hari ini kamu buka puasa dimana dan bareng siapa? Di-share yuk!',
#  'Halo 3 hari ini sinyal padahal LTE tp kok internetnya suka ga jalan itu kenapa ya? @myXLCare',
#  'Min, mau tanya untuk booth di mall Cijantung hari ini buka gak ya?  Kalo buka ada dilantai berapa ya?  @myXLCare',
#  'Terkuat dari mana buka youtube aja buffer terus @XLAxiata_Tbk @myXLCare #JaringanDataTerkuat',
#  'Halo kuota khusus untuk nonton netflix ada ga ya? @myXLCare',
#  'Halo @myXLCare ini knp kuota saya hangus ya setelah beli paket xtra combo?',
#  'Halo @myXL @myXLCare , saya barusan menghubungi layanan 818 untuk up limit XL Pascabayar saya, tetapi infonya sistem sedang dalam perbaikan. Lalu saya harus hub ke mana ya? Karena saya butuh segera. Thanks',
#  'Min @myXLCare kok tiba tiba di nomor gue ada nsp slank sih? Boleh tolong dimatiin nspnya?',
#  'Kenapa nmr CS XL gak bs dicall semua??? emang gak ada nmr lain??? @myXLCare @myXL',
#  'Ini XL gaada rencana mau maintenance jaringan di daerah Sempur, Bogor yah? Cuman awal doang bagus disini. Makin kesini, tiap menit selalu "Request Timed Out". Mau gitu terus apa gimana? Gaada perkembangan nih payah selalu turun masalah jaringan. @myXLCare',
#  'Admin @myXLCare tlg cek DMnya ya. Tq',
#  'Dear @myXLCare sinyalku tiba2 hilang ni dari pagi..padahal pas tadi sahur baik2 aja..mind if u check my num?? is it ok? https://t.co/N9Ug4AiSvY',
#  'Min @XLAxiata_Tbk @myXLCare  mhn tlg dibantu saya mo aktifasi pake prio GO tapi belum ada balesan dan potongan di limit https://t.co/a5m4qitHc8',
#  'Alhamdulillah jaringan XL-Axis sudah pulih lagi,setelah hampir 2 minggu down @myXLCare @ask_AXIS https://t.co/e8GZKrUzfC',
#  'dear @myXLCare  \n@XLAxiata_Tbk  mau sampe kapan ni udah di stop tiba tiba kepotong pulsa nya buat bayar RBT sangat bikin tak betah tiba tiba berlangganan EBT yg ga JELAS https://t.co/TpplF0mY32',
#  'Min @myXL @myXLCare  jaringan XL lg knpa sih dr semalem ilang2 mulu muncul2 E skrg 4G tp cuma sebatang dua batang lemot nya paraahh nihh. Tlp ke 817 blg nya lg under maintenance. Ampuunnn deehh puasa2 bikin bete aja 🤦',
#  'Pake Prioritas tapi ngga bisa activate iMessage. Berkali-kali coba, mentok terus. Gimana nih @myXLCare ??? \nSkrg pake iOS 12.2',
#  'Malam kak, mau tanya kenapa yaa di sekitar jalan karangsari-kebo iwa denpasar sinyalnya minim banget? @myXLCare',
#  'Dear @myXLCare  tolong dong peningkatan jaringan yang suka hilang',
#  'gak usah may ngerepotin, udah ganti ke telkomsel juga lagian gua. https://t.co/uhVVYngD1G',
#  'Terima kasih XL atas internet lemot nya saya jadi sadar mana yang lebih baik @myXLCare',
#  'Selamat sahur! Share menu makan sahur kamu hari ini dong :) Jangan lupa baca niat puasa dan sholat subuh ya :)',
#  '#JaringanDataTerkuat setahuku hanya @Telkomsel tapi kini jaraingannya makin buruk (katanya sedang peningkatan siatem) . \n\nJaringan Terbaik lainnya \n@smartfrencare \n@myXLCare \n@ask_AXIS \n@IndosatCare \n@triindonesia',
#  'Sore tadi nyobain @JakartaMRT dari Blok M-Bundaran HI (PP), signal @myXLCare langsung ilang begitu MRT masuk trowongan. Di sebelah bapak2 yg masih asyik chating entah pakai provider apa 😣',
#  'paketan saya kok belum diperpanjang ya? @myXLCare @myXL',
#  'Ini @myXLCare kenapa sih sinyal ogah ogahan',
#  'Min @myXLCare  jaring apa lg jelek ya..',
#  'Dear CS @myXLCare cara untuk pindah dari XL Pascabayar (XL prio) ke Prabayar ini bisa langsung kah?',
#  'Halo @myXLCare gimana ini jaringannya???!!!!ud 4g ga bs dipake sm skli skrg 3g ny cm 20K/s, bener2 sampah bgt pelayanan xl!!diapain kek spy bs dipake minimal, ini cm bisa nya minta sabar2 melulu!!!',
#  'Admin xl @myXLCare kenapa sinyal XL jelek.. internetnya super lemot.. lama2 ganti nomer juga nih',
#  'XL parah bgt sinyalnya udh seminggu😭😭😭 udah tlp ke customer service 3x beda2 hari nggak ngaruh apapa😭😭😭 @myXLcare\n\nBikin tweet ini aja ke kirimnya bisa stgh jam😭',
#  'Halo @myxlcare kenapa setiap saya kalo abis isi kuota baru pasti sinyalnya sendet banget??? Tolong bantuannya',
#  'Kembali seperti biasanya koneksi bermasalah terutama malam @myXLCare ampe bosen tiap malam komplain',
#  'Tolong di bantu jaringan sangat buruk @myXLCare @myXL',
#  'Jaringan @myXLCare kacau parah ... jaringan lola sangat',
#  'Sebelnya kalo isi pulsa gini nih, pasti tiba2 kepotong sama konten2 yg gak jelas. Tanpa daftar atau apapun tiba2 ke register sendiri. Bikin KZL @myXLCare https://t.co/EcL8iZ95PH',
#  'Aduh @myXLCare knp lagi sih... padahal jarinangan 4G loh tp buka smua aplikasi buffering gt.. kirim pesan jdi pending smua.. 😠😠😠😠',
#  'Ramadhan ini akan semakin indah jika kalian juga sedekah kuota tanpa S&amp;K 😅\n@smartfrencare @Telkomsel @3CareIndonesia @ask_AXIS @myXLCare',
#  'Futsal..  Maen jam 5 sore,  pas beres langsung buka https://t.co/qtk0pWwXBX',
#  'Selamat sore, siapa nih yang mengisi waktu ngabuburitnya dengan berolahraga? Share dong olahraga favorit kamu di bulan puasa apa?',
#  'Xl ngeselin dari kemarin ih-_- sinyal full tapi lemot banget😭 @myXLCare',
#  'Halo @myXLCare knapa 2 minggu ini sinyal xl jadi jelek bgt sih?',
#  'Dear @myXLCare , can u help me? aku mau pakai xl buat bayar google play, kok ga bisa mulu ya? selalu muncul error xl payment method not eligible',
#  'Mohon maap udah beli paket xtra combo yang VIP kenapa masih lemot nih padahal jaringan 4G tapi buka instagram aja gabisa bisa @myXLCare',
#  'Hay XL, bantu sy no terblokir apa bs d hidupkan lagi https://t.co/z7Sm1d6ZKi',
#  'Hi @myXLCare please check dm,thank you.',
#  'Hi @myXLCare , nomor saya terus dikirimin sms seperti ini. Kmrn katanya telfon di CS sms seperti ini di nomor saya sudah di block karena memotong pulsa? https://t.co/OlbR9ODAJB',
#  'kok saya terus2an dapet sms gini ya? padahal internetannya gapake kartu xl @myXLCare https://t.co/zhSg3HGsjj',
#  'selamat siang mau tanya untuk daerah kota tangerang khususnya ciledug lagi eror yah jaringanya kok dari semalem no service terus? @myXLCare',
#  'Sinyal jelek banget, 4g aja engga😠 @myXLCare',
#  'Ini keluhan saya gimana @myXLCare ...??? Sudah 2 minggu, dan sudah 5x saya telpon, hasilnya NIHIL https://t.co/iNX5BZm1sz',
#  'Pagi minta, @XLPrioritas @myXLCare pasca bayar saya di rumah ko ga dapat sinyal ?? &amp; ga aktif',
#  'Dear Admin @myXLCare , saya mengalami lagi persoalan pulsa berkurang, padahal saya tidak melakukan apa2 dr handset saya. Persis dgn persoalan yg saya keluhkan C22217833 &amp;C22217835, sebelumnya. Tolong perhatian dan kebijakannya. Cc @kemkominfo @CCICPolri',
#  'Hi @myXLCare klo kartu axis udah abis masa tenggang, mw diaktifin lagi, gmn caranya?',
#  'Baru ngisi kuota kok jadi tambah lemot sih koneksi nya min ? @myXLCare',
#  'Bodo amat https://t.co/rLWQxA2rbV',
#  'Selamat pagi, gak terasa sudah 5 hari menjalani ibadah puasa. Masih semangat kan puasanya? Jangan sampai bolong ya :)',
#  'Beberapa hari ini mau pesen ojol dimanggarai rada susah. Sinyal xl jelek banget :"( jadi suka was-was gitu padahal harus berpacu dengan waktu biar bisa sampe kantor tepat waktu. Tolong jaringan di stasiun manggarai dicek :( @myXLCare',
#  '#jaringan XLdown https://t.co/xPjuSeYteP',
#  'Dear @myXLCare kenapa paket kouta mobile legend nya gak bisa di beli...?',
#  'Ini signal XL di Sapugarut, Buaran, Pekalongan, Jawa Tengah kok tiba-tiba selepas hujan hilang kenapa ya @myXL @myXLCare https://t.co/qeviEovGcY',
#  'Bila anda berpikir bahwa jaringan @myXLCare kasrut...jangan gampang nuduh, ini sebetulnya saya sedang berusaha masuk aplikasi xl dengan jaringan @IndosatCare ....makanya kasrut... https://t.co/dK4YBCduwM',
#  'Setelah ganti ke pasca bayar kenapa sinyal malah susah ya :) @myXLCare',
#  'Jaringan @myXLCare belakangan nggak bersahabat ada apa gerangan??',
#  'Selamat bertahan di Salty Spiton !!!\nSeberapa Greget Anda, @MyXLCare https://t.co/bKcqISI1KS',
#  'Dear @myXLCare XL center Banda aceh sekarang dimana ya? Soalnya di daud bereueh udah tutup, mau ganti kartu ni',
#  'Kambing bener sumpah ini XL @myXLCare  -_- makin hari makin lemot yaallah. Fix ganti provider. Say NO to XL!!👎🏻👎🏻',
#  'Dear @myXLCare kenapa udah 4 hari ini jaringan xl begitu jelek. Biasanya bagus. Hmm wa ku masih berjalan tapi agak lemot sih. Terus instagram nggak jalan sama sekali. Kenapa xl kuuuuu @myXLCare',
#  'Halo @myXLCare ini kenapa lemot bgt yaaaa internetnya',
#  'Lagi lagi lagiiiii @myXLCare \nTiap malam sinyal selalu jelek, lost connection, bahkan tadi siang juga, sudah seminggu ini',
#  'Entah kebetulan atau tidak, bagaimana caranya nomor ponsel ini bisa tahu nama saya dan kirim SMS tidak penting? @myXLCare https://t.co/tCKblAtVyp',
#  'Kenapa si xl selalu bikin pulsa kepotong😠 Pdhal kuota paketnya msh banyak @myXLCare',
#  'Tidak bisa diandalkan ketika cuaca buruk adalah salah satu ciri khas @IndosatCare .Terima kasih karena sinyal hilang tiba2 saya kehujanan dan tidak bisa order @gojekindonesia atau @GrabID !! Saatnya beralih ke @myXLCare atau @Telkomsel #indosatbikinsakithati',
#  'Kebahagian saya adalah jika saya sebagai pelanggan pasca bayar mendapat pelayanan baik dan kualitas jaringan yang bagus https://t.co/JChJeaRHvs',
#  'nengcntq Hi! Maya akan coba bantu lakukan pengecekan dengan tim myXLCare ya😊. Kamu bisa message nomor dan pertanyaan terkait melalui twitter myXLCare agar dapat dibantu ditindaklanjuti. Semoga cukup membantu, terima kasih😇',
#  'Selamat berbuka puasa! Ini salah satu takjil favorit Maya lho ketika buka puasa. Takjil favorit kamu apa? Share ya :) https://t.co/MDsnFdCUzX',
#  'Min apaakh @myXLCare mengadakan Kuis seperti SMS dibawah ini Tks.. https://t.co/ehLN0Z16WH',
#  'Jaringan 4G nya kacau, muter muter doang udah 2 hari.. tolong bantu @myXLCare',
#  'Untuk kesekian kalinya @myXL @myXLCare nyedot pulsa dengan cara tiba2 didaftarkan ke layanan sms berlangganan premium tanpa sepengetahuan saya...',
#  'Bingung Saya..\n\nMau komplain C22209482 masalah bonus langganan Iflix &amp; 3 bulan Hooq di nomer prioritas @myXL @myXLCare ini mau follow up setelah hari minggu laporan di Grand Indonesia..\n\nFollow up di XL CSB..EH MASA HP GW DI BAWA2 KE DALAM TANPA PERMISI..INI SOP NYA EMANG GITU?!',
#  'sekar_padma Hi! Maya akan coba bantu lakukan pengecekan dengan tim myXLCare ya😊. Kamu bisa message nomor dan pertanyaan terkait melalui twitter myXLCare agar dapat dibantu ditindaklanjuti. Semoga cukup membantu, terima kasih😇',
#  'sekar_padma Hi! Maya akan coba bantu lakukan pengecekan dengan tim myXLCare ya😊. Kamu bisa message nomor dan pertanyaan terkait melalui twitter myXLCare agar dapat dibantu ditindaklanjuti. Semoga cukup membantu, terima kasih😇0myXL',
#  'Hai @myXLCare knpa gak bisa buat buka apk kaskus ya sdangkan buat apk lainnya normal aja itu',
#  'Kenapa tiba tiba saya berlanhganan ini? @myXLCare https://t.co/QjZO73ekDD',
#  'Hallo mau tanya, untuk status nomer saya gmna ya? Apa sudah aktif untuk yg prioritas? Kmrn saya di call di tawarkan untuk diubah jadi prioritas, sudah kirim data belum dpt info lagi. @myXLCare',
#  'Min @myXLCare di daerah Depok Cimanggis, kok kalo jam10 malam ke atas, sinyalnya bapuk bgt yak. Pake paket mahal jg sama bapuk internetnya. Ga bisa browsing apa2, update twitter aja sulit..',
#  'Bahkan xl ngirimin ginian @myXLCare https://t.co/L4d2pRjDOH',
#  'saya minta pulsa dikembalikan, oleh @myXLCare @XLAxiata_Tbk malah dijawab kaya gini. kesannya menyalahkan pelanggan. coba pikir pake logika, mana ada keledai jatuh di lubang yg sama 2 kali https://t.co/lbU2KR7kRG',
#  'mana bentuk tanggung jawab dari @XLAxiata_Tbk @myXLCare tentang kebohongan yg sudah dilakukan terhadap saya ? https://t.co/MHnMslEE2E',
#  'perusahaan sekelas @XLAxiata_Tbk @myXLCare bisa2 nya kasih janji palsu. kataya sudah diblokir, tp yg terjadi tetep pulsa saya disedot, dan lagi2 dari nomor yg itu2 saja. bullshit ! https://t.co/RyTbuPZosW',
#  'Ko sinyal @myXLcare makin kesini makin menolol ya\n\nHilih Kintil',
#  'Jaringan @myXLCare lagi error yaakk',
#  'Jatingan @myXLCare kenapa sih?? Buat download gambar dan video di wa aja susah banget',
#  'Selamat siang, masih semangatkan puasanya? Share dong kegiatan apa yang kamu lakukan disiang hari ketika berpuasa?',
#  'Dear @myXLCare apakah tdk ada solusi lain dr kalian selain konsumen yg disuruh pindahin simcard ke hp lain, restart hp, nanyain ke semua pengguna xl sinyal kembangkempis. Sinyal mau di bekasi, jkt sama ngenesnya!!',
#  'Baru sadar pulsa terkuras sedikit demi sedikit untuk layanan sms yang tidak pernah saya daftarkan dan berlangsung lama tampaknya.. emang XL bisa seperti itu ya @myXLCare ?',
#  'Pagi @myXLCare team. Apakah saia masih bisa cetak sim card yg sudah hilang beberapa bulan lalu. jika iya, apa syarat nya.   Terimakasih',
#  'Fix! Tetep sama @myXLCare Kaum missqueen kek saya gini 800mb doang jadi masalah yaa :( sedih. https://t.co/LKCpT5NX1O',
#  'Hi min @myXLCare apakah saat ini sdg ada optimasi jaringan di Jawa Timur? Hari ini Xl gak bs dipake sama sekali. Sinyalpun hilang.',
#  'Min ini maksudnya apa sih? Gak pernah registrasi beginian tp tiba2 pulsa kepotong, tolong lah min @myXLCare https://t.co/Bb6WLE28kb',
#  'Dear Admin @myXLCare terimakasih sudah menjawab keluhan kami nomor C22217833 &amp; C22217835, dan bahkan menyelesaikannya dengan amat baik. Cc @kemkominfo @ChatibBasri',
#  'Halo sudah di DM yah https://t.co/SD2HYtzoOZ',
#  'Halo @myxl @myXLCare dari kemarin jaringan XL mati total, di desa sungai undan, kec. Reteh, kab. Indragiri hilir, prov. Riau',
#  'Cape urusan sm @myXLCare tiap dm ganti2 org trs dan dm atw laporan kita ga dicatat jdny hrs ngulang2 trs!!!tolong lah ksh penjelasan yg jelas kapan jaringan di daerah sy bs normal, 1bln?2bln?1 thn? jgn ksh jwbn kosong tnp dateline!! https://t.co/DdR7o8Evx5',
#  'Udh di DM ga dijawab, bad rate.\nCall 2x ke 817 cuma action reset dari sisi pusat, nyuruh2 restart. Gada Hasil.\n\nKalo ga bisa nyediain layanan berkualitas gausah iklan iklan pake priority, nyatanya koneksi busuk.\n\nKECEWA @myXLCare https://t.co/AeP6B8xMA2',
#  'knp sinyal @myXLCare kok sampah???!!!!!!!!!!! bsgtgst',
#  'xl kenapa nih ko lemot bgt si ilang ilangan lagi @myXLCare',
#  'Haluuu @myXLCare gimana nih jaringannya gangguan terus percuma akutuu pake prioritas tp kendala mulu hmmmm masa tiba2 sos bahkan buat buka aplikasi kalian aja muter doang :))))',
#  'Astagaaaaaaaaaaa yaTuhaaaaaaaaan sinyal XL @myXLCare',
#  'Wawwww keren bngt ya sinyal nya mana numpang tower lagi dan jauh pula dari rumah w 🙃🙃🙃🙃 @myXLCare https://t.co/lXR2edYkj9',
#  'Hello @myXLCare ,kenapa 2 hari ini layanan internet lambat dan cenderung tidak bisa ? Apakah ada gangguan ?',
#  'sedih banget udah 2 hari sinyal xl @myXLCare begini. lemot dan bener2 kosong dan cm dirumah gak ada sinyalnya. kalo tempat lain bisa. aya naon ini teh? :( https://t.co/Yyt3PENRu3',
#  'Bosen https://t.co/WWFxfBYkld',
#  'Malam min. Saya dari sekitar jam stgh 7 sinyalnya 3G dan skrg malah No Service. Sudah di restart sama aja. Apa ada gangguan di daerah Pamulang? Terima kasih @myXLCare',
#  'mohon konfirmasinya @XLRECORDINGS @myXLCare @myXL saya sudah mengikuti alur untuk memasukan voucer ini. tapi jawaban yang saya dapatkan seperti ini:\n\nMaaf, kode voucher atau nomor MSISDN yang anda masukan salah. Info 817 https://t.co/dMox31yjCR',
#  'Ini no xl ga di pake apa2 tapi plsanya berkurang terus ya @myXLCare nyuri dong ..',
#  'Good night,my internet connection is so poor. I breathe with internet and having trouble with my internet connection means i am going to suffer. Please fix it @myXLCare. Thank you',
#  'Komplain ke @myXLCare bolak balik ditanya merk hp, alamat.....sinyal elu tai ngapa jadi alamat',
#  'XL masiiiihh aja lemooootttt! Sampe kpn sih, min? @myXLCare 😡',
#  'apaan jaringan VIP prioritas, buka twitter aja lalod amat @myXLCare',
#  'udah 3 hari ini setiap malam internet super lemot, bahkan tiap mulai jam 10 malam ga bisa dipake internet nya sama sekali. tolong diperbaiki dong!! @myXLCare',
#  'Suka aneh sama @myXLCare udah stop paket masih aja narik pulsa dengan alasan tarif dasar/mb. Mau untung bgt',
#  'BUSEEEEEEEETTTTTTTTTTTTTTTTT https://t.co/TyOueg789H',
#  'Halo @myXLCare jaringan di waingapu belum stabil atau ada masalah? Lelet pke banget',
#  'Bulan Ramadhan, bulan penuh #XtraRejeki! Gak percaya? XL meluncurkan paket terbaru yaitu, Paket Xtra Rejeki. Seperti apa ya paketnya? Yuk, simak #XLShare malam ini! https://t.co/pphUyLl9VH',
#  'ini xl kenapa ya kok rada  gak stabil waktu buka sosmed kadang bisa kadang enggak  @myXLCare',
#  'Hai myXLCare saya beli XL voucher kuota internet, sudah mengikuti petunjuk penggunaan tp tdk bisa terisi dan muncul "Maaf, nomor anda tdk bisa menerima transfer paket" pdhl biasanya bisa. Kenapa ya?',
#  'Parah nih @myXL masa punya 2 paket internet (yg lama yg combo, yg baru beli combo vip) tp internet dan menit telp terpotongnya dr yg baru (vip), hrsnya potong dr paket lama dulu dong (yg tinggal 2 hari masa berlaku). @myXLCare',
#  'Selamat berbuka puasa! Hari ini kamu buka puasa bareng siapa? Share ya :)',
#  'Ikut paket xtra combo @myXLCare... no.1 and no.2 ko tiba2 ikut sich ??? Pantesan pulsa cepet abis... ada auto sedot pulsa @XLAxiata_Tbk https://t.co/7SAn6MWz4i',
#  'Kenapa jaringannya sekarang jd lemot ya? @myXLCare',
#  'Ini gimana?? @myXLCare @myXL \nSudah 4 kali komplain, samsek tdk ada perubahan.. https://t.co/pruSZEBsF9',
#  'Mantap no service ni @myXLCare',
#  'tidak ada ujian paling berat dalam berpuasa melebihi pake @XLAxiata_Tbk @myXLCare 😂😂😂',
#  'Dear @myXLCare, maaf saya mau menyampaikan keluhan mengenai jaringan..sudah beberapa hari ini beberapa dari kami yg menggunakan XL mengalami gangguan jaringan, suka tiba" tidak ada koneksi pada saat sedang online..tolong  diperbaiki agar tidak mengecewakan kami..terima kasih..',
#  'Hi @myXLCare ada ga batasan wkt utk 1 pelanggan di layanan di customer care? Ini udh lebih dr 30 mnt hanya 1 org ga jalan antriannya. Yah wlopun ada 2 desks (Prioritas) &amp; bbp meja lain.. hanya nanya. Tks\nFyi, lokasi di Xplore Lotte Avenue',
#  'Mohon dibantu kak, saya ada beli paket XL 37GB masa aktif 60 hari diketerangan, tapi pas 30 hari langsung habis, mohon penjelasannya @myXLCare',
#  'Halo min @myXLCare apakah bisa berbagi kuota internet ke sesama XL?',
#  'Ada yang tau cara melenyapkan content penganggu ini??!!!! Melaporkan kemana ya!!  @YLKI_ID @myXLCare @XLAxiata_Tbk https://t.co/NXilzk4Ulk',
#  'Saya ingin blokir no xl saya yg hilang, mohon dibantu @myXLCare',
#  'tiap siang dan sore jaringan sllu gini\n.malam apalagi..ga bsa mulu.. tlong @myXLCare jaringan @XLAxiata_Tbk',
#  'Gimana ya caranya cek kalo kartu kita termasuk ke sp whitelist? Soalnya aku gabisa aktifin xtra combo lite. Makasih @myXLCare',
#  'Aku pake XLGo dan mau cek kuota di XLink. Aku tekan *123# tapi cuma keluar sisa pulsa sama masa aktif aja. Ga ada pilihan cek kuota. @myXLCare',
#  'You suck @myXLCare',
#  'Baru isi kuota lho @myXLCare XLCare tapi cuma kebagian sinyal satu bar doang. Ga connect pula, hp sampe panas 😪 https://t.co/Fjzz70FfLF',
#  'Udah 2 hari sinyal @myXLCare ilang, ngentot lu ah https://t.co/gYLTuU7NFP',
#  'Hallo @myXLCare mau tanya, jam operasional XLC Ciputra World selama bulan Ramadhan? Terima kasih',
#  'Halo min! Barusan sy beli voucher internet, terus waktu sy registrasi, ada balasan “Maaf, kartu anda tidak dapat menerima transfer paket”. Bisa dijelaskan maksudnya apa? @myXLCare',
#  'Dear @myXLCare ini gimana ceritanya ya kok bisa nomor hp saya terdaftar ke akun gak jelas? Padahal saya gak pernah daftar, tiba2 cek pulsa saya yg dari 20ribuan jadi tinggal seribu 😰😓 Dan kejadian ini ternyata banyak dialami org2 sekitar saya. Harus unreg sendiri lg. 😰 https://t.co/1kHmw8OV4g',
#  'sinyal @myxlcare &amp; @ask_axis gmn sih dr smlem mpe skrg ga connect buat internetan !!!!',
#  'Belum pernah tertarik yang namanya langganan RBT sejak dulu, tiba² ada perpanjangam RBT @myXLCare. Gak tau udah berlangsung berapa lama ini. https://t.co/aVLFwvooNH',
#  '😑😑 https://t.co/dqjsdyVGBb',
#  'Dear operator XL, ini kenapa ya koneksinya sering hilang begini? Sering ga dapet signal, tolong diperbaiki kualitasnya 🙏 @MyXL_Jabar @myXLCare https://t.co/l4pEmSVmwD',
#  'Dear @myXLCare untuk stop semua layanan seperti ini bagaimana yah? Saya ga pernah sengaja langganan https://t.co/FQZDt4B2ql',
#  'Min @myXLCare ada lagi... Moodmusic, sya sja tdk tau ni layanan dan sya tdk pernah kirim sms setuju/OK/Langganan, cuman 11rb tapi ..... rasanya Min https://t.co/Mrewe5gQ5k',
#  'Selamat sahur! Coba absen dulu yang sudah bangun sahur siapa aja?',
#  'Bro bener banget,  ane juga sama, udah pindah2 tempat dari SCBD,  cipulir sampai blok m aja ga terhubung ke internetnya kan nyesek mau update kerjaan (cc @myXLCare ) https://t.co/icHPEMTzG8',
#  'xl saya cacad lagi @myxlcare',
#  ':|| Gini terus, tapi di dm juga gak ada solusinya. Thanks. https://t.co/lLgxRe4J22',
#  'hallo min @myXLCare , knp ya sinyal xl lg naik turun . kzl pdhl pke combo vip tp ga vip :((',
#  'makasih @myXLCare masalah lemot gue beres . Good Bye @IndosatCare . Kmren bukan ancaman doank kann... gue buang kartu indosatnya , capek hati. https://t.co/IkJJdW9VGm',
#  'Tiap jam 10 malam @myXLCare maintenance data connection ya? Ada yang rasain juga? \n\nCS-nya ditanya sampe kapan.. gak tau juga katanya 😩',
#  'Malam admin, mohon cek DM ya. Terima kasih @myXLCare',
#  'Halo @myXL @myXLCare  4G+ anda njomplang cukkk',
#  'mohon maap teman2 Twitter, saya lg sangat amat gondok dengan pelayanannya xl @myXLCare ASLIIIII💩💩💩💩',
#  "Buka buka ig mantan min, siapa tau bisa jadian lagi:') https://t.co/2JPhrUSOPn",
#  'Selamat malam @myXLCare sinyal internet ditempat sy naik turun,mohon segera dibenahi!!1!!11',
#  'Malam kk @myXLCare kenapa saya tidak bisa melakukan pembayaran dengan pulsa untuk pembelian item di google play, mohon pencerahannya',
#  'Lagi lagi dan lagi, setiap malam selalu lost connection @myXLCare',
#  'B4b1 https://t.co/C4rzKbUt3s',
#  'Hai kak, mau tanya klo aku mau ganti paket sisa kuota di paket lama akan terakumulasi apa hangus? @myXLCare',
#  'Ada apa sih 2 hari ngga bisa dipakai telepon ke operator manapun? Bahkan nggak bisa menghubungi 817. @myXLCare @XLAxiata_Tbk',
#  'Sudah 8 hari Paket Super-Ngebut XL ngebut-nyebur ke #Bong200 No laporan C22193961, tak ada tindaklanjut dari @myXL\n@myXLCare',
#  'CS nya hanya normatif saja, masak kita sbg pelanggan pascabayar masih didata, apa tdk percaya ya?\n@myXLCare https://t.co/kqDZVJqNo2',
#  'Bener bener lu ya @myXLCare',
#  'Min aku udah transfer pembayaran paket prioritas tapi kok gak ada motif masuk ya kalau aku udah transfer? @myXL @myXLCare',
#  'Whatsapp-an sama site manager minta kirimin long section proyek https://t.co/jVFSoTMtgO',
#  'Saya kalu DM didata melulu, jadi malas https://t.co/GVixTTZIaD',
#  'Mau muntah rasanya sama sinyal XL gak 3G gak 4G LEMOT BANGET kenapa sih @XLAxiata_Tbk @myXLCare',
#  'Sebenernya migrasi ke xl prioritas itu menguntungkan konsumen atau engga?  Min @myXLCare?\n\nBeberapa hari lalu, sy migrasi ke xl prioritas dengan harapan (dan janji telemarketing)  jaringan yang lebih bagus..\nNamun nyatanya setelah migrasi,  internet malah naik turun..',
#  'Halo @myXLCare kecepatan kok gini gmn? https://t.co/GiKDSkbVoZ',
#  'Maya @myXLCare sinyal XL daerah Cilandak Jaksel knp sangat minim ya? Smp network not available',
#  'Halo @myXLCare udah 3 hari ini kena telpon dari nomer ini. Bisa diinformasikan itu nomer apa? Terimakasih https://t.co/kO6GqIhFXB',
#  'Haduh koneksi xl di serang parah seminggu ini tolong dong benerin @myXLCare , kecewa ni sama layanan xl prioritas',
#  'Hancurkan GALERY &amp; SEMUA PEGAWAI @myXLCare @myXL .\nKALIAN YANG MEMULAINYA SEJAK BULAN JANUARI 2019.\n\nData2 sudah lengkap , kalo cuma pake hukum perdata saja, saya gak puas karena akan ada korban lainnya.\n\n@DivHumas_Polri bongkar penipuan @myXLCare @myXL @XLAxiata_Tbk',
#  'BAPAK POLISI YANGBTERHORMAT DANBSAYA HORMATI.\n\nDimana saya bisa melaporkan TINDAKAN PENCURIAN DISERTAI PERAMPASAN HAK SESEORANG yang dilakukan oleh perusahaan komunikasi. \nYang sudah sering meresahkan konsumen.\n @DivHumas_Polri \n @myXL @myXLCare',
#  'RAPAT STAF 😭😭😭😭😭😭😭 https://t.co/wehNwBPhDr',
#  'Nungguin dia bales tapi di-read aja ngga sampe sekarang :) https://t.co/U6ibnPyaQt',
#  'Operator yang merangkap jadi penipu  \n➡️@myXL @myXLCare \n\n2x PEMOTONGAN KUOTA REGULER PADAHAL ADA KUOTA MALAM..\n\n3X PULSA DI EMBAT MESKIPUN PUNYA KUOTA AKTIF..\n\n1X PAKET HILANG TANPA PEMBERITAHUAN...\n\nKALO BEGITU KONSUMEN YANG DIRUGIKAN DONG @DJPPIKominfo @kemkominfo',
#  'Selamat sore, kamu biasanya melakukan apa sih sambil menunggu waktu buka puasa? Share ya :)',
#  'Ogahmalesmauboboaja https://t.co/84RMgktCMt',
#  "Min ini ada kuota youtube 10gb tapi kok kalo youtube'an yg kepake yg internet 24jam ya @myXLCare https://t.co/dt5ZXu9vDb",
#  'Jaringan @myXLCare kalo udah kumat gini jelek bgt hadeeh',
#  'Hay admin saya mau nanya, kenapa no KK saya tidak bisa buat kamu registrasi? Alesan no KK tidak terdaftar di dukcapil, tapi dari dukcapil bilang nomer KK nya sudsh terdaftar.\nMakasih @XLAxiata_Tbk @myXLCare',
#  'Hai admin myXLCare saya baru beli kartu XL. Sudah terdaftar, tapi kenapa selalu mendapatkan notifikasi "anda sedang menikmati internet dengan tarif normal" padahal blm aktifin paket data dan selalu terkuras pulsa saya. Mohon bantuannya min.',
#  'Hai admin @myXLCare saya baru beli kartu XL. Sudah terdaftar, tapi kenapa selalu mendapatkan notifikasi "anda sedang menikmati internet dengan tarif normal" padahal blm aktifin paket data dan selalu terkuras pulsa saya. Mohon bantuannya min.',
#  'min @myXLCare mau unreg layanan yg teregistrasi gmn?',
#  'Apa kabar @myXLCare sudah sejak bulan Oktober 2018 sampai hari ini sinyal XL/AXIS lelet sekali. Kapan ada perbaikan? Mau download video/aplikasi saja harus berkendara 1 km dari rumah. Hebat ya?',
#  'saya heran dengan @myXLCare aplikasi Xl prioritas tidak bisa menampilkan sisa quota internet kok tidak segera ditangani.. ini terjadi pada pengguna lain juga. https://t.co/h8QnLwYkG9',
#  'hallo @myXL @myXLCare , jaringan xl di area rumah sy kdg suka down , mohon bantuannya!',
#  'Tolong @myXLCare ,, kalo promo jangan pakai modus yg menguntungkan sepihak,, klo ndak balas sms di anggap iya, kalo balas sms dibalas tidak,, promo RBT macam apa itu? Kami juga ndak butuh RBT mu,, bukan promo namanya,, modus pencurian pulsa baru',
#  'Min @myXLCare  tadi saya ditelp oleh +62818 gak keangkat,, kira2 ada apa ya ☺️🤔 ???',
#  'Ini kenapa signal XL seminggu terakhir ini like shit @myXL @myXLCare',
#  'ini XL dr semalem No Service mulu @myXLCare ada apa ya',
#  'Apa yang lu harepin dari kecepatan seadanya ini, kalau kekuatan sinyalnya aja cuma segitu? @myXLCare https://t.co/q9ZxDfo66z',
#  'Aduh engga sadar. Kebiasaan emang ini operator suka nyuri nyuri  @herrysw @myXLCare https://t.co/emD1yh3eiN',
#  'Ini XL daerah kelapa gading kenapa ya? Kok LTE nya gabisa kepake. Bener2 ga jalan sama sekali @myXLCare',
#  'Selamat pagi, tetap semangat menjalankan ibadah puasanya yaa bagi yang menjalankan :)',
#  'min @myXLCare masa tenggang kartu XL brapa lama ya?',
#  'Signal hancur banget @myXLCare  😰',
#  'Sekesal itu sma @myXL ini jaringan nya bisa2 nya naik turun naik turun 4g trus ke 3g gitu aja terus kek lg pushup... Kalau ga kemakan iklan yg katanya jaringan stabil g bakal mau gw makai ni kartu @myXLCare -_-',
#  'Halo @myXLCare apa XL bisa tranfer pulsa ke operat lain?? Dan kalo bisa bagaimana cara nya',
#  'Haloo @myXLCare , gimana ini pembayaran Google play via pulsa XL kok ga bisa?? Padahal kemaren bisa tolong pencerahan nya',
#  'Apakah xl ada maintenance? @myXLCare https://t.co/Xo2ekJU5Tu',
#  'XL ada jaringan 4G ngga min? @myXLCare',
#  'Buseh bisa gila gak tuh ping kek kode SDSB Speed kek jaman gprs ... yg pk @myXLCare pasti dah pasrah keadaan kek gini. https://t.co/Nk2g0nQybc',
#  'Sinyal bro @myXLCare huhu',
#  'Halooo xl ku bermasalah lagi seperti kemarin malam:)) @myXLCare',
#  'Allahu akbar signal kamu @myXLCare',
#  'Min @myXLCare sinyal xl ditempat saya sudah parah sekali, padahal menggunakan xl prioritas, tidak berpengaruh, sinyal 3g lebih baik dari LTE nya, walaupun 3g sudah buruk LTE lebih buruk lagi',
#  'Hai @myXLCare , saya butuh care kamu terkait sinyal yang tidak care terhadap kebutuhan onlineku. Saya butuh pembuktian sinyal 4.5G kamu.\n\nSedikit terjamah sembilan hari menuju cut off. https://t.co/vxNMbbRPsJ',
#  'Luar biasa @myXLCare, kalian provider baik..',
#  'Sampai besok (7/5/2019) sinyal XL @XLAxiata_Tbk @myXLCare masih gak stabil. Gue ganti kartu Telkomsel @Telkomsel, for freaking good. Gapapa bayar mahal yg penting sinyal terjamin. Sorry not sorry XL',
#  'nomor xl saya kenapa ya no service terus? bisa bantu aktifkan kembali? @myXLCare',
#  'Min @myXLCare sampe kapan nih lemot" kayak gini signalnya!? Udh 3 hr bgini, jd ngandelin wifi kmn".. Ribet! 😪😪😪 ahelahh',
#  'Roti min https://t.co/fO6YLs4kc4',
#  'Selamat berbuka puasa! Share dong menu buka puasa kamu hari ini :)',
#  'Wanan siapa? https://t.co/zTmZnD7Bvz',
#  'min @myXLCare internetan susah, paket data ada tp gk mau hidup2 internet y, bapuk..',
#  'Hay @myXLCare saya sudah berhenti dari @XLPrioritas  Untuk deposit nya bisa kembali dalam brp hari ya? Sudah 60 hari',
#  'bales dm dong sumpah ya kecewa banget sama admin xl nya @myXLCare',
#  'agustianirita28 Hi! Maya akan coba bantu lakukan pengecekan dengan tim myXLCare ya😊. Kamu bisa message nomor dan pertanyaan terkait melalui twitter myXLCare agar dapat dibantu ditindaklanjuti. Semoga cukup membantu, terima kasih😇',
#  'suzan_kusuma Hi! Maya akan coba bantu lakukan pengecekan dengan tim myXLCare ya😊. Kamu bisa message nomor dan pertanyaan terkait melalui twitter myXLCare agar dapat dibantu ditindaklanjuti. Semoga cukup membantu, terima kasih😇',
#  'ach_zahid07 Hi! Maya akan coba bantu lakukan pengecekan dengan tim myXLCare ya😊. Kamu bisa message nomor dan pertanyaan terkait melalui twitter myXLCare agar dapat dibantu ditindaklanjuti. Semoga cukup membantu, terima kasih😇',
#  'nunuchanu Hi! Maya akan coba bantu lakukan pengecekan dengan tim myXLCare ya😊. Kamu bisa message nomor dan pertanyaan terkait melalui twitter myXLCare agar dapat dibantu ditindaklanjuti. Semoga cukup membantu, terima kasih😇',
#  'MHDWAL1 Hi! Maya akan coba bantu lakukan pengecekan dengan tim myXLCare ya😊. Kamu bisa message nomor dan pertanyaan terkait melalui twitter myXLCare agar dapat dibantu ditindaklanjuti. Semoga cukup membantu, terima kasih😇',
#  'grisdaaa myXLCare Hi, mohon maaf atas ketidaknyamanannya🙏🏻. Boleh tolong diinformasikan dimana lokasi kamu dan apakah rekan di lokasi kamu menghadapi hal yang sama? Maya sarankan kamu untuk restart device kamu dan coba akses kembali. Semoga cukup membantu, terima kasih 😊',
#  'gitashelli Hi! Maya akan coba bantu lakukan pengecekan dengan tim myXLCare ya😊. Kamu bisa message nomor dan pertanyaan terkait melalui twitter myXLCare agar dapat dibantu ditindaklanjuti. Semoga cukup membantu, terima kasih😇',
#  'sudah sebulan lebih layanan data xl tidak bisa dipakai di cijantung, kata @myXLCare @myXL @XLAxiata_Tbk nunggu tambah jaringan baru,entah sampe kapan selesai nya,ini cijantung jakarta lho brooo @aduanBRTI',
#  'Signal muncul 1-2 BAR ,bahkan 3 BAR pun tetap sulit mengakses. https://t.co/eZ9n91Pd3H',
#  'Hallo jaringan saya 4G tidak stabil bahkan berganti jadi 3G pun tetap sama ,baru kali ini terjadi gangguan sekitar hampir 2 minggu ini biasanya baik-baik saja. Tempatnya dirumah ,tapi terkadang ada beberapa daerah dijalan yang bad signal juga. Thx https://t.co/eZ9n91Pd3H',
#  'Min saya mau nanya agak lucu nih @myXLCare \n \nSaya lagi di kuningan jakarta ga jauh lah dari XL tower di kuningan juga. Kok bisa ya pengguna XL lagi dibawah XL tower yang tinggi itu, terus di tengah-tengah ibu kota lagi bisa ga ada sinyal gitu? Mau bangkrut atau emang lagi busuk?',
#  'Ah lumayan dibagi pulsa sama xl https://t.co/RRPtX0Dp24',
#  'Hai, min @myXLCare.\nSaya ak merasa langganan RBT kalian. Tapi berapa bulan yl pulsa saya dipotong utk langganan.\n\nLalu saya unsub dan dikonfirmasi oleh 1818 saya telah berhenti langganan.\n\nTapi tadi 1818 memberitahu langganan saya diperpanjang, pulsa dipotong 3000+.\nKok bisa?? https://t.co/Z54tsyRdNd',
#  'Min saya kan pernah pakai kartu xl nah karna saya jarang pakai kartu xl tersebut otomatis jd di non aktifkan nah saya sekarang butuh nomor tersebut untuk update data e-money saya, bisa bantu di aktifkan kembali nomor yg saya ga min @myXLCare @myXL',
#  'Indikator signal 4G , tapi loading banget bahkan cuma buat load tweet doang. @myXL @myXLCare',
#  'Apa cuma saya disini yang merasakan xl bad signal akhir-akhir ini? Mengganggu aktifitas bgt😭 @myXL @myXLCare @XLAxiata_Tbk',
#  'So bagi yang pake XL hati2 aja sama iklan SMS @myXL @myXLCare karena ternyata bukan cuman saya yg ngalami keluhan kendala dr XL,, ini sambil curhat ada juga keluhan dr MANTAN pengguna XL laennya #RamadanMubarak',
#  'Dari kemarin tosoon gara2 sinyal jelek bahkan gaada, buat maen patah2, ping kuning merah terus. Tolong @myXLCare ! https://t.co/NPPrvasoZG',
#  'Hari pertama puasa udah baper sama jaringan @myXLCare .cuk cuk cuk',
#  'Udah min @myXLCare https://t.co/UELJ4GjAwi',
#  'Halo, bisa tolong cek kenapa pulsa saya terus berkurang? Seingat saya, saya tidak menggunakan pulsa untuk hal hal lain kecuali internet. @myXLCare https://t.co/17oDb3ktOS',
#  'Dear @myXLCare apakah saat ini ada maintenance jaringan di Jawa Timur? Kecepatan akses internet bbrp hari ini menurun banget.',
#  'Marhaban Ya Ramadhan. Selamat menunaikan ibadah puasa 1440 H. Semoga ibadah puasanya lancar sampai tiba di hari kemenangan :) https://t.co/U6XctUOAjZ',
#  'Cobaan puasa 1 : signal XL luar biasa menguji kesabaran pagi pagi saat butuh pesen ojek hhhh @myXLCare',
#  'Xl down kah? Posisi jakarta timur pekayon pasar rebo\n @myXL  @myXLCare',
#  'Selamat pagi @myXLCare ini jaringan xl lagi lemot yah jaringannya lagi kenapa nih',
#  'Jaringan @myXLCare belakangan sering bermasalah ada apa sebenarnya??',
#  'Baikan dong puasa gaboleh musuhan @myXLCare @ShopeeID https://t.co/9Gxff0pNcF',
#  'Kesel sih. tiap minggu pulsa dipotong terus.. kok sepihak bgt sih? Tiba2 langsung otomatis perpanjang RBT. Daftar jg enggak!! @myXLCare https://t.co/u63Grosty2',
#  'Xl sumpah bikin emosi , terus ajah tiap bulan eroro alesan perbaikan jaringan dari kapan tau selalu begini 4G tapi koneksi gak ada ! @myXLCare @myxl',
#  'Kenapa si @myXLCare akhirnakhir ini koneksi internet lemah banget, sampe stream youtube aja buffering?!',
#  'Koneksi jaringan Internet XL kok jelek gini yah? @myXLCare \nLambat banget, buat streaming aja susah.',
#  'Ini xl lagi gangguan atau gimana ya? Dari jam 10 malem engga dapet koneksi sama sekali. Buruk banget jaringannya. @myXLCare',
#  'Halo min, akun instagram saya selalu mengirimkan kode ke nomor XL lama saya yang sudah hangus dan hilang simcard nya sehingga saya tidak bisa log in lagi. Apakah nomor lama saya dapat dibangkitkan lagi min @myXLCare ???',
#  'bang masa dikatain bang @myXLCare setrum aja bang pake tower eksel. https://t.co/wSQrDohFfw',
#  'Halo @myXLCare tiba2 aku gabisa internet sama sekali tp signal msh 4G, udh dari jam 11 tadi kenapa ya? Lokasi di Depok',
#  'Oey min @myXLCare 4G XL ini lagi maen kemana suruh pulang lah daritadi ditungguin gak muncul2',
#  'Promo VIP Weekend Tipuan ini sebaiknya di non aktifkan di aplikasi myxl @myXLCare ,,, biar tidak ada korbak HOAX seperti saya ....\nPromo masih berjalan , di beli gak bisa , apa Nggak disebut NIPU !! https://t.co/N22ch2bSd2',
#  'Beneran gak nih, tanpa kuota di jam 1-6 utk akses youtube? @myXL @myXLCare https://t.co/S4aEAHMF9l',
#  'Hallooo min  mau tanya apakah harin ini xl sedang gangguan? @myXLCare',
#  'kenapa kamu lemot banget padahal sinyalnya 3-4 batang @myXLCare',
#  'Dear maya @myXLCare\nJingan oug kenapa pulsa daku tetiba berkurang, pdhl jarang daku gunakan.\n#fyi daku utk tlp pake paket telp, dan paling utk mobilebank itupun tergolong jarang.\n\nAsu ada vampir di XL',
#  'Tolong dong konektivitasmu asu bbrp hari terakhir ini @myXLCare',
#  'Min @myxlcare @myXL kok sinyal xl jelek banget sih sekarang! 3g dan 1bar aja. Bikin gak bisa ngapa2in',
#  'Masih percaya promo @myXLCare  komplainan  STATUS C22208371 , \nSudah lama gak ada tanggapan, \nIni promo atau Hoax??? \nKeterangan nya banner nya promo sampai tgl 5 mei 2019 ,promo nya jika beli pake pembayaran yang lain lain,\nSaya beli pake cc,tp error ..niat promo gak @myXLCare https://t.co/ijOOlocfy8',
#  'Halo, @myXLCare selamat malam. Saya mau tanya. Ini kenapa kartu saya pulsanya tersedot entah kemana ya? Saya tidak pernah mendaftarkan paket apapun dan pemakaian tlp juga hanya sesekali dan sebentar.  Mohon bantuannya. Trims.',
#  'Ini dari beberapa tahun lalu ya disini jaringan sdh 4G, hp sdh canggih. Tp akses internet parah lemot banget @myXL @myXLCare @MyXL_Jabar',
#  'tolong dong ke depannya @myXLCare jangan bekerja sama dengan pihak ke 3 yang kerjaannya cuma mencuri pulsa\nsiapa pihak ke 3 itu ???yg membuat rugi saya 😡😡\njangan cuma minta maaf, tapi musnahkan pihak ke 3 itu \U0001f9d0\U0001f9d0 https://t.co/E9RD7FZnfz',
#  'Bro @myXLCare mohon infonya. Ini kenapa sinyal 4G nya kenceng. Tapi speednya jelek ya? Ada ganguan kah?',
#  'YANG KASIH IZIN BERLANGGANAN SIAPA? Ini penipuan @myXLCare @XLAxiata_Tbk @YLKI_ID @BareskrimPolri 1 pelanggan 3.300 kl 1juta pelanggan dah brp duit NGERAMPOK nya? PER MINGGU PULA. Mohon Perhatian @kemkominfo ... @jokowi https://t.co/ZRdgbuKDPe',
#  'Hallo @myXLCare @myXL apakah dr xl ada otomatis pasang RBT di no hp pelanggannya? Selama ini saya ga pernah ngeh, sampai pas hp saya ilang &amp; coba tlp pake hp org lain.. ada RBT nya ternyata.. mana lagunya alay lagi.. plisss pantesan pulsa cpt bgt abisnya..',
#  'Skor di bawah nol untuk @myXL\n@myXLCare #6Hari Paket Internet diblokir',
#  'No case\nC22193961. Enam hari tanpa tindaklanjut @myXL @myXLCare #Bong200',
#  'Dear @myXLCare jaringan xl sedang gangguan kah? Karna sudah 3harian saya utk internetan susah bgt.',
#  'Udah seminggu ini XL kenapa ya? Gaada sinyal trus lemot bgt kalo chat @myXLCare',
#  'Sebelum pasang paket roaming XL, apakah harus sudah pasang paket internet biasa juga? Mohon infonya @myXLCare . Soale paket roaming mama saya engga bisa dipake ceunah.',
#  'Sebuah konsistensi @myXLCare ☺👍🏻 https://t.co/aQT17Mpv87',
#  'Cara ngilangin beginian gimana? @myXLCare @aduanBRTI https://t.co/GVgIeYfIUV',
#  'Cek dm @myXLCare',
#  'Min jaringan xl saya kenapa jelek bgt si :( 😭 sebel @myXLCare',
#  'Kak bisa diberhentiin ga sih ini? Sumpah ganggu banget. Tolong kak udah mau bulan ramadhan nih @myXLCare https://t.co/ygjnyIPHXl',
#  'Min @myXLCare @myXL, kenapa dari semalam sinyal XL H± mulu? Jadi lamban beut.. 😑😑',
#  'Padahal di Jakarta tapi cukuplah, cukup gak pakai lagi. @myXLCare',
#  'another "colongan" pulsa dr @myXLCare @myXL | sim1 xl juga tp pasca dan emg paket data on. sim 2 xl, tanpa paket apapun...  pantes 2 no xl di hp yg beda pulsanya cepet abis... https://t.co/v16VrmmrEi',
#  'hi min myXLCare , aku mau minta tolong untuk turunin batas limit kartu pascabayar-ku ya.\nterima kasih.',
#  'Knp skrang jaringan @XLAxiata_Tbk @myXLCare  @myXL Sering lag saat main game online 😑 Sdngkan youtube lancar lancar aja tuh😑 lama lama pindah ke kartu perdana sebelah aja dh gua klo jaringan 4g ttp nge lag main game online😑',
#  'Halo @myXLCare @XLAxiata_Tbk mohon dibantu, sepertinya sinyal XL gangguan terus dr kemarin di area tertentu di denpasar',
#  'Ganggu bangeuuuddd niyy @myXLCare matiin nape, aku ga pernah register loh pdhl, please! https://t.co/hfMiQtipss',
#  'Sudah 2 hari sinyal 4g di kamar saya hilang nih min @myXLCare',
#  'kenapa ya pake kartu @myXLCare pas buka aplikasi @ShopeeID ga bisa dibuka ya ? -,-\n\nPadahal udah direstart mulu :)',
#  'XL = Xlalu Lemot ketika hujan ataupun sehabis hujan.\n\nKatanya Kuat &amp; Stabil, mana? Cuma dapet 30 Kb/s di jaringan 4G mana cuma dapet 3 bar lagi sinyal-nya.\n\n@myXL @myXLCare https://t.co/mZcSqUZNoI',
#  'Mengadu pun jawabannya kayak mesin @myXLCare \nAmpun ampun pelayanan di negara negara ber flower raflesia, bacin',
#  'kenapasi kalo sinyal full gini malah kg bs dipake? @myXLCare https://t.co/ER5cTMAM6r',
#  'Gangguan min xl prio di denpasar sekitar gatot subroto. Baik di hp atau modem xl home. HP sinyalnya hanya H dan XL Home disconnected terus. https://t.co/vRf4vBksyO',
#  'XL makin kesini makin mengecewakan, padahal berlangganan sudah tahunan\n@myXLCare 😫 https://t.co/7h1MGq7YLM',
#  'hallo @myXLCare, ini sinyal knp kok ilang2 mulu utk daerah jatiwarna. padahal td saya ke daerah tebet lancar. pas pulang lgsg lemot lg. udh 2 hari lho ini',
#  'Dear @myXLCare tolonglah XL, sinyal hpku tidak stabil 2 minggu ini. Sdh berusaha k XL Center dan diganti simcard (krn rusak, katanya). Then tlp 817. But, still ga ada perubahan. Sedih akutu 😭 😭 😭. Aku hrs bgmn lagi??',
#  'Speed internet 4G XL mantaaap 😂😂🤣 @myXLCare @myXL https://t.co/EpZNOrMrSZ',
#  'halo @myXLCare saya mau berhenti berlangganan paket roaming combo saya, sudah 2x coba stop via ussd tapi blom distop juga, bisa dibantu?',
#  'Baru tau dong nomer hp gw ada ringtonenya, gatau lagu apaan itu, gapernah daftar pake ringtone apa2. Please cara berhentiin ringtonenya gimana? @myXLCare @XLAxiata_Tbk',
#  'Apa bisa di buat telp ke 021, soalnya saya ada pascabayar yg ada telp ke semua operator 250 menit, tp kepotong ke saldo saya ya... https://t.co/SiNEYXzUsk',
#  'Tolong sudah 2 hari ini internetan lemot sekali area Gresik-Lamongan\n@myXLCare @ask_AXIS @AXISgsm',
#  'Halo, @myXL @myXLCare. No case C22193961 tanggal 30 April, kenapa tidak ditindaklanjuti? #XL200 #Bong200',
#  'Min cara aktifikan kembali kartu xl yg udh kena masa tenggang gmn ya? Saya mau isi pulsa tp nmr tidak terdaftar. Mohon bantuannya min @myXLCare',
#  'Minta solusi nya sinyal slow kalau buat internet... sayang2 kuota jdi gak kepake terus @myXLCare @myXL',
#  'akubedil myXLCare Hi! Maya akan coba bantu lakukan pengecekan dengan tim myXLCare ya😊. Kamu bisa message nomor dan pertanyaan terkait melalui twitter myXLCare agar dapat dibantu ditindaklanjuti. Semoga cukup membantu, terima kasih😇',
#  'ErolzAlfath myXLCare Baik, terima kasih telah memilih XL menjadi provider kamu ya. Tetap dukung XL selalu, selamat berakhir pekan 🤗',
#  'mhon bantuan penanganannya @MyXL_Jabar  @myXL @myXLCare   untuk sinyal daerah bojong herang cianjur sinyal gangguan sejak kamis, info dari teman',
#  'Siang @myXLCare mau tanya bedanya xtra combo biasa sm VIP apa ya? Thx you']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



df = pd.DataFrame(tweet_text, columns=['text'])
#df = pd.read_csv("data/hasil14julii.csv",header=None, names=['text'])
df.head(10)
# Out:
#                                                 text
# 0         #2019GantiPresiden https://t.co/odpEtoWTCL
# 1  Bertawakallah! Berusaha sampai maksimal dan se...
# 2  Kuatkan tekad #2019gantipresiden https://t.co/...
# 3  Kalau DPR sudah menyetujui pertanda DPR tidak ...
# 4  Orang itu..sering yg diomongkan beda dengan ke...
# 5  Insyaallah menang..\n#2019GantiPresiden #2019P...
# 6  #2019gantipresiden\n\nSesuai dengan amanah dar...
# 7  ada aja perang kok lawan spanduk poster bukan ...
# 8  Ini hebatnya Calon Pemimpin yg berani jujur\n#...
# 9  Membayangkan kalau mereka semua berkumpul di g...

# %%
from nltk.tokenize import WordPunctTokenizer
import re
from bs4 import BeautifulSoup

tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9_]+'
pat2 = r'https?://[A-Za-z0-9./]+'
pat3 = r'#[A-Za-z0-9]+'
pat4 = r'\[A-Za-z0-9]+'

combined_pat = r'|'.join((pat1, pat2, pat3,pat4))
#combined_pat = r'|'.join((combined, pat3))

def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?") 
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z0-9]", " ", clean)
    lower_case = letters_only.lower()
    words = tok.tokenize(lower_case)
    parsedData = [s.replace('b ','', 1) for s in words]
    parsedData1 = [s.replace('\nb', '') for s in parsedData]
    return (" ".join(parsedData1)).strip()


testing = df.text[:10000]
test_result = []
for t in testing:
    test_result.append(tweet_cleaner(t))
    
test_result
# Out:
# ['',
#  'bertawakallah berusaha sampai maksimal dan serahkan segala sesuatunya kepada allah swt insya allah apa yang terjadi di jakarta akan berulang di level nasional aamiinkan bro untuk memimpin negeri ini',
#  'kuatkan tekad',
#  'kalau dpr sudah menyetujui pertanda dpr tidak peduli thd keamanan suara rakyat dpr perlu dipertanyakan pada ngapain aja kok meloloskan kardus sebagai kotak suara pemilu',
#  'orang itu sering yg diomongkan beda dengan kenyataan',
#  'insyaallah menang',
#  'sesuai dengan amanah dari guru ngaji saya yang seiman pasti tau alasannya',
#  'ada aja perang kok lawan spanduk poster bukan capres kedunguan yg haqiyuqiyu',
#  'ini hebatnya calon pemimpin yg berani jujur prabowo subianto sadar diri untuk tidak menjadi imam salat',
#  'membayangkan kalau mereka semua berkumpul di gelora manahan solo',
#  'woisss pecah bergemuruh insyaallah',
#  'akhlak dia tak punya adab dia tak punya otakpun dia gak punya dia pantas terima penghinaan dia manusia hina',
#  'perlu di klarifikasi di mana letak kesejahteraan masyarat papua era yg beritakan di berbagai media karna fakta papua kekurangan sdm sehingga mengalami tingkat pengangguran dan kemiskinan di pemerintahan',
#  'jelas',
#  'kalau presiden pak harus didepan kalau imam solat ya ulama yg didepan jangan memaksakan kehendak semua ada aturan dan tata caranya',
#  'asalamualaikum sambut pagi dgn senyum manis salam perjuangan prabowo sandi salam kemenangan pas 60 jokoruf 40',
#  'opm serahkan diri tni mereka lihat pembangunan papua makin maju west papua',
#  'perumpamaan yg sangat masuk akal',
#  'harga sawit turun jokowi minta petani tanam jengkol dan petai kmrn2 bpk usul utk universitas membuka fak kelapa sawit krn potensi yg msh bsr lah skrg kok anjurannya berubah usulnya fak apa yg fixed fak kelapa sawit pete apa jengki',
#  'terima saja amplopnya kaosnya pilihan tetap no 2 no 2',
#  'allah swt selalu membalas tunai tingkah laku mereka',
#  'niat mau membuly ustad haikal caleg psi husinshihab malah ketauan simpan gambar porno',
#  'ah sudah lah ferguso',
#  'jelang bebas 24 januari mako brimob akan serahkan ahok ke lapas cipinang apapun beritanya',
#  'live di tv uji coba kekuatan kotak suara kardus hampir jebol diduduki petugas kpu apapun beritanya',
#  'bersaing2 dgn baik pakai akal sehat jgn main robek2 spanduk',
#  'apresiasi kejujuran prabowo fahri hamzah lebih baik punya umara penguasa yang tidak benci ulama daripada umara sudah gak paham agama pakai benci ulama lagi',
#  'survei internal ma ruf amin hambat elektabilitas jokowi',
#  'ketika tangan dan kaki tak sanggup menopang raga tenang masih ada hati yang tetap mengusung rasa',
#  'setelah kasus capture vc di galeri akun tutup bubar sabar bentar lagi setelah pemilu jga juga akan tutup bubar cici dah kehabisan modalnya',
#  'monggo bagi pecinta ulamak yg cerdas dan istiqomah',
#  'ini dikasihkan ke tim pas saja saat debat pilpres pas bahas kesejahteraan petani tunjukin ini saja ke petahana beres',
#  'next leader insya allah jadi presiden saya',
#  'luhut bertemu jokowi sampai malam di istana bahas apa apapun beritanya',
#  'negeri yang subur sayuran impor dari china bps catat naik usd 57 juta apapun beritanya',
#  'belum kantongi izin iklan grace natalie psi diturunkan satpol pp apapun beritanya',
#  'jangan sampe isu baliho ini sampai lupa tagih janji jokowi kekejaman komunis thd muslim uyghur mengkampanyekan program pro sand kasus kasus ketidakadilan hukum jgn terkecoh permainan cebong kasus baliho sudah di tangani polda riau tinggal kita awasi',
#  'karena beliau bukan pembohong kami tidak suka di bohongi',
#  'hancurnya tipudaya politik rombengan dinamika politik pekan kemarin bisa disebut sebagai pekan hancurnya tipu daya kaum yang sok pamer kuasa warganet pro perubahan gembira para perindu keadilan tersenyum ceria',
#  'aamiin',
#  'perubahan itu akan terjd dan waktunya sdh amat sgt dekat cebong2 yg tak sadar2 akan kegilas oleh perubahan itu sendiri',
#  'sama orang partai dr daerah saja spt ini bagaimana kalau pusat ya',
#  'sangat amat gak mungkin ini ngawuur org madura patuh komando hrs patuh perkataan kyai pkb pastikan jokowi ma ruf amin bakal menang di madura via jatim',
#  'kesimpulannya jujur itu mengakui dan sadar diri akan kemampuan yg dimiliki bukan mamaksakan diri',
#  '',
#  'hahahah dia memang sontoloyo omongan dng perbuatan tidak sikron',
#  'menghayal terus kapan nikahnya',
#  'jadi kepling pun dia tidak pantas',
#  'video tampil live tes kekuatan kotak suara petugas kpu hampir jatuh apapun beritanya',
#  'go',
#  '',
#  'wajib akhiri ini semua di',
#  'morning all dunia maya akan selalu bergemuruh seperti biasanya tapi kita tidak hidup disana dunia nyata tetaplah menuntut kita untuk fokus merajut asa menggapai cita cita selamat beraktifitas yuk mari ngampus dulu kita dan tetep ya',
#  'mati ajalah kau mukidi biar kembali damai indonesiaku gak ada otak kau',
#  'll penipuan guy s dibagikan setahun lalu saldo kartu tani tak kunjung terisi',
#  'semoga bapak presiden 2019 bapak selalu dalam keadaan sehat wal afiat',
#  'mak2 militan dr kubu prabowo sandi khususnya dr sudah berulang kali terjun langsung ke pasar tradisional kapan yaa ibu2 bangsa dr kubu jainuddin blusukan ke pasar tradisional saran sy jgn lp pakai helem biar aman klu diamuk oleh mak2 di pasar',
#  'anggaran naik cuma buat beli kardus sebaiknya periksa apa ada kerugian negara kecuali selain kardus lebih kuat dari aluminium juga lebih mahal alasan menghemat kok anggaran naik ckckck ada apa dengan otak',
#  '',
#  'cepatlah kau mati mukidi biar kembali damai indonesiaku',
#  'kita kita kita',
#  'pengen liat pendukung jokowi yang begitu banyaknya d medsos tp d dunia nyata ternyata ghoib',
#  'ncu kluarin juga dunk surah ayat hadits atau apa kek yg bisa perkuat alasan menentang poligami eh gimna kabar',
#  'pola komunikasi dan koordinasi yang aneh untuk sebuah kabinet susi meminta kemendag kurangi impor garam',
#  'hahahaha capee deeewwwh',
#  'biasa si jaenudin mah gitu katanya merakyat tapi rakyat yang manaa',
#  'konferensi nasional gerindra kalo udah seperti ini rasa2 nya pak dah berasa jadi presiden ri dech duhh dah gak sabar 2019 nich',
#  '',
#  'pembangunan membutuhkan kestabilan keamanan dengan keberadaan kelompok opm di suatu daerah hal tersebut berarti menghambat pembangunan di daerah tersebut west papua',
#  'bergetar hati liat video ini',
#  'ngedit terus dikasih angka terus ada tanda persennya mah anak kecil juga bisa kali bong wkwk',
#  'yang pusing lihat pemerintah impor garam terus bukan hanya nelayan dan rakyat indonesia',
#  'kotak kardus pesanan cukong karena kertas kardus barang dagangan cukong',
#  '',
#  'ternyata kardus tahan air maksudnya tahan air didalam kardus kalo basah dan terendam',
#  'beda kelakuan beda ucapan',
#  '',
#  'pak mul suka bolak balik makna kata kali ya',
#  '',
#  '',
#  '',
#  '',
#  'bukan karena pak yai ma tapi memang krn faktor rakyat sdh pengen lha selama 4 th lebih malah rakat sumpek dan susah lha trs gmn lagi',
#  'takut sama yang punya kejaksaan',
#  'lapangan kerja terbuka luas untuk rakyat indonesia bukan untuk tka china nanti yg udah terlanjur bertebaran di nkri ini krn rezim jainnudin dideportasi aja',
#  'kasihan amat tuh taman',
#  'mukidinya kemana lg pasang meteran listrik ngurus kerdus ngurus baliho',
#  '',
#  'pagi yg cerah secarah indonesia menuju adil dan makmur',
#  '',
#  'wah cebong bisa kelojotan nih',
#  'nasehat gurunda uas dlm memilih mata boleh jadi bdusta krn tdk bs melihat kayu yg bengkok di tepi sungai kelihatannya bengkok padahal dia lurus oleh sebab itu kita mesti cerdas dalam hal ini gunakan telinga mata dengan baik',
#  'padahal sudah tapi tetap saja bonusan gak bertambah jangan cuma pekerja asing saja yang bertambah',
#  'semoga makin banyak yang tobat',
#  '',
#  'momen yang paling tidak bisa saya lupakan tahun ini adalah bersiap siap untuk tahun depan',
#  'kita kita kita',
#  'siap 86']

# %%
df1 = pd.DataFrame(test_result, columns=['text'])
#df = pd.read_csv("data/hasil14julii.csv",header=None, names=['text'])
df1.head(10)
# Out:
#                                                 text
# 0
# 1  bertawakallah berusaha sampai maksimal dan ser...
# 2                                      kuatkan tekad
# 3  kalau dpr sudah menyetujui pertanda dpr tidak ...
# 4  orang itu sering yg diomongkan beda dengan ken...
# 5                                  insyaallah menang
# 6  sesuai dengan amanah dari guru ngaji saya yang...
# 7  ada aja perang kok lawan spanduk poster bukan ...
# 8  ini hebatnya calon pemimpin yg berani jujur pr...
# 9  membayangkan kalau mereka semua berkumpul di g...

# %%
import pandas as pd
import re
import string
import nltk

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
stemmer = StemmerFactory().create_stemmer()

pd.set_option('display.max_colwidth', 500)

stopwords = nltk.corpus.stopwords.words('indonesian')
ps = nltk.PorterStemmer()

 

#data_clean
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-310e9ff098c3> in <module>()
#       4 import nltk
#       5
# ----> 6 from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
#       7 stemmer = StemmerFactory().create_stemmer()
#       8
#
# ModuleNotFoundError: No module named 'Sastrawi'

# %%
word_list = {'qt':'kita','trims':'terima kasih','minn':'min','gmn':'gimana',
 'connection':'koneksi','bkn':'bukan','tdk':'tidak','sdh':'sudah',
 'bales':'balas','bls':'balas','kcw':'kecewa', 'haloooo':'halo', 
 'jgn':'jangan','bgt':'banget','kgn':'kangen','knapa':'kenapa','skr':'sekarang',
          'quota':'kuota', 'prbaikan':'perbaikan','jarngan':'jaringan', 'skli':'sekali',
           'iye':'iya', 'yaaa':'iya','emg':'memang', 'emang':'memang',
           'jaringam':'jaringan', 'kaya':'kayak','kya':'kayak',
          'sdh':'sudah','kalo':'kalau', 'yng':'yang','dg':'dengan', 'luemoooottt':'lemot',
          'baut':'buat','kenapaaa':'kenapa','hsri':'hari','mlm':'malam','sekarangg':'sekarang','dpt':'dapat'}

def cleaning_text(text):
    text = ''.join([word.lower() for word in text if word not in string.punctuation])
    tokens = re.split(' ', text)
    for index, data in enumerate(tokens):
        for key, value in word_list.items():
            if key in data:
                tokens[index]=data.replace(key, word_list[key])
    text = [stemmer.stem(word) for word in tokens if word not in stopwords]
    #text = re.sub(","," ",str(text))   
    text = " ".join(text)
    #text = re.split(" ", text)
    return text

data_clean['cleaned_text'] = data_clean['body_text'].apply(lambda t: cleaning_text(t))
#data_clean.head(1100)
print('wes bersih rekk')
# Out:
# wes bersih rekk

# %%
word_list2 = {'gak':'tidak'}
def data_clean1(cleaned_text):
    cleaned_text = ''.join([word.lower() for word in cleaned_text if word not in string.punctuation])
    tokens = re.split(' ', cleaned_text)
    for index, data in enumerate(tokens):
        for key, value in word_list2.items():
            if key in data:
                tokens[index]=data.replace(key, word_list2[key])
    #text = [stemmer.stem(word) for word in tokens if word not in stopwords]
    #text = re.sub(","," ",str(text))   
    cleaned_text = " ".join(tokens)
    #text = re.split(" ", text)
    return cleaned_text

data_clean['clean_text'] = data_clean['cleaned_text'].apply(lambda t: data_clean1(t))
data_clean.head(1100)
# Out:
#                                                                                                                                                                                                                                                          body_text  \
# 0                                                                                                                                   ini dari jam 19 34 sampe sekarang kenapa sinyalnya ilang lokasi dusun pereng desa sendangsari pengasih kulon progo wates jogja
# 1   hi roleplayer mohon maaf atas hal ini saat ini sedang ada peningkatan kualitas jaringan di lokasi tersebut saat ini bagian terkait sedang menangani masalah ini berusaha menyelesaikannya sesegera mungkin alasan sejak 4 bln lalu tiap dikomplain eoql sinyal
# 2                                                                                                                                            min jika msh langganan paket internet lalu beli paket haji apakah langganan paket internet yg msh berlaku akan hangus
# 3                                                                                                                                   dear kenapa makin hari koneksimu makin bikin emosi jujur kualitasmu jauh lbh bagus sebelum bergabung di jaringan miss that day
# 4                                                                                                                                                                                                                               xl center di bintaro dimana ya min
# 5                                                                                                                                                                           jaringan ada tapi saya coba telp nomor tersebut masih belum bisa nyambung terima kasih
# 6                                                                                                                                                                              kok xl daerah batu ceper sinyalnya 3g ya ga 4g gangguannya kira kira sampe kapan ya
# 7                                                                                                                     min mau tnya kouta saya masih sisa 6gb tapi tdak bisa di pake buat internetan dua kartu sama semua kendala ngestack di 6gb ga bisa buat inet
# 8                                                                                                                                                                                                                                      bye gue mau beralih ke tsel
# 9                                                                                                                                                                               min kok sinyal nya masih jelek juga ya ngirim wa aja ke pending sinyal nya 3g pula
# 10                                                                                                                                                                                                                                                guys dinotice xl
# 11                                                                                                                                kenapasiiii xl hembel bangetttt youtube gabisa soundcloud gabisa browsing lama sya disuruh mengheningkan cipta aja nih maksudnya
# 12                                                                                                                                                      xl kenapaaa dari kemarin dri jam 8mlm dah signalnya ilang ini smpe skrg pending molooo pdhl udah direstart
# 13                              haloo saya mau tanya untuk kuota 24jam di 2g 3g 4g area itu bagaimana ya apa hanya dibatasi di area tertentu tentunya membuat rugi konsumen apalagi sisa kuota saya sampe 6gb dan tidak bisa digunakan mohon direspect terimakasih
# 14                                                                                                    pengen maki maki aja jshdsh kenapa sih lemot banget kalo buka twitter sumpah pake indos t aja ga se lemot ini mana yang katanya sinyal stabil cepet darimana
# 15                                                                                                                                                                                    hp gua ada 2 dua nya beda provider jaringan dan dua nya lemot bazengan emang
# 16                                                                                                                                                                                                                mas mba jaringannya putus putus ada apa gerangan
# 17                                                                                                                                                                                            kenapa saya mau daftar paket xl xtra combo selalu muncul seperti ini
# 18                                                                                                                                                              jam segini kok maintenance jgn keseringan maintenance ah gabagus kl it nya gabecus potong gaji aja
# 19                                                                                                                                                                                                                          tlg balas dm saya admin m17 hhhhhhhhhh
# 20                                                                                                                                dear please stop spamming my phone with your pop up ads mengganggu banget loh iklan pop up nya masa tiap buka hp ada iklan terus
# 21                                                                                                                                                                                   kalian bisa kerja gak sih kalo gabisa ngasih solusi ga usah ada customer care
# 22                                                                                                                                                                                                                        jaringan 4g lagi kenapa sih lemot banget
# 23                                                                                                                                                                                            xl lagi kenapa ya mas mba di daerah kp cadas kec legok kab tangerang
# 24                                                                                                                                                              saya isi paket 10gb diskon 40 pulsanya ketarik tapi kuotanya ga masuk gmn ya nomornya 081908294489
# 25                                                                                                                                                                                                                                               tlg balas dm saya
# 26                                                                                                                                                           jaringan internet xl lagi kenapa yah udah 4g lte kok lemot banget masa kalah sama 3g nya telkomsel cc
# 27                                                                                                                                                                                                   selalu xl tiap malem begini mau buka aplikasi apapun lemotnya
# 28                                                                                                                                                                                                                   internet by macam indihome dipake ku 6an saja
# 29                                                                                                                                                          ini saya isi paket 10gb diskon 40 pulsanya ketarik tapi kuotanya ga masuk gmn ya nomornya 081908294489
# 30                                                                                                                                                                                      misi atulah kenapa ini xl aku jelek banget koneksi nya ngga load gitu masa
# 31                                                                                                      saya kira ganti paket dari xtra combo jadi paket hotrod bakalan ada perubahan ternyata enggak ya tiap liat twitter masih kayak gini gini aja ini kenapa ya
# 32                                                                                                                                                                                                          lagi ngapa si dr siang koneksi internet nya ancur gjni
# 33                                                                                                                                                                      lapor jaringan untuk daerah sungai ulin banjarbaru kalsel gangguan sejak sore tadi makasih
# 34                                                                                                                                                                                                                                              cek dm min makasih
# 35                                                                                                                                                                                                                    cara berhenti berlangganan xl prio gimana ya
# 36    halo selamat sore saya mau tanya saya baru registrasi no baru nih kak lalu saya sudah sesuai dengan instruksinya yg memaksukan daftar nik kk kirim 4444 namun saya ada kendala ni kak diliat di fotonya yaa itu bagaimana kak tolong fast respon terimakasih
# 37                                                                                                                                                                                       gamau lagi beli kuota di aplikasi myxl diskon ya ternyata zonk huuuuuuuuu
# 38                                                                                                                                                                                                                     min ini apa ya sering bgt muncul ganggu bgt
# 39                                                                                                                                  min ko ibu sy mw dftar baru kartu xl tulisanya kartu sdh mmenuhi kuota pdhl ibu sya blm prnh dftar min itu ko bisa ada yg pake
# 40                                                                                                                                                                        ini gimana sih kuota masih bejibun tp ko kena pemakaian kb jangan kaya indosat dong plis
# 41                                                                                                                                                                                     sebel sama katanya diskon 17k ternyata ngga sia sia beli pulsa 100k akuuuuu
# 42                                                                                                                                                                                                       parah ni paket data padahal udah 4g xl di bekasi timur cc
# 43                                                                                                                                                                                                           selamat sore no saya kok gak bisa buat tlp dan sms ya
# 44                                                                                                                                                                                                                                                      min bca dm
# 45                                                                                                                 johanfjr ularb0yz myxlcare 2 untuk pelaporan silakan kirim sms dengan format penipuan sms tipuan tersebut kemudian kirim ke nomor 1166 tks endo
#
#                                                                                                                                                 cleaned_text  \
# 0                                                               jam 19 34 sampe sinyal ilang lokasi dusun reng desa sendangsari asih kulon progo wates jogja
# 1                                          hi roleplayer mohon maaf tingkat kualitas jaring lokasi kait tangan usaha selesai alas 4 bln komplain eoql sinyal
# 2                                                                          msh langgan paket internet beli paket haji langgan paket internet msh laku hangus
# 3                                                                                   koneksi bikin emosi jujur kualitas lbh bagus gabung jaring miss that day
# 4                                                                                                                                     xl center bintaro mana
# 5                                                                                                               jaring coba telp nomor nyambung terima kasih
# 6                                                                                                          xl daerah batu ceper sinyal 3g ga 4g ganggu sampe
# 7                                                                                tnya kouta sisa 6gb tdak pake internetan kartu kendala ngestack 6gb ga inet
# 8                                                                                                                                              bye alih tsel
# 9                                                                                                               sinyal jelek ngirim wa aja pending sinyal 3g
# 10                                                                                                                                          guys dinotice xl
# 11                                               kenapasiiii xl hembel bangetttt youtube gabisa soundcloud gabisa browsing sya suruh hening cipta aja maksud
# 12                                                           xl kemarin dri jam 8malam dah signalnya ilang smpe sekarangg pending molooo pdhl udah direstart
# 13                                           haloo kuota 24jam 2g 3g 4g area batas area rugi konsumen sisa kuota sampe 6gb tidak mohon direspect terimakasih
# 14                                          ken maki maki aja jshdsh sih lot banget buka twitter sumpah pake indos t aja ga lot sinyal stabil cepet darimana
# 15                                                                                                                    hp 2 beda provider jaring lot bazengan
# 16                                                                                                                               jaring putus putus gerangan
# 17                                                                                                                         daftar paket xl xtra combo muncul
# 18                                                                           jam gin maintenance sering maintenance ah gabagus kl it gabecus potong gaji aja
# 19                                                                                                                         tlg balas dm admin m17 hhhhhhhhhh
# 20                                                           please stop spamming my phone with your pop up ads ganggu banget loh iklan pop up buka hp iklan
# 21                                                                                                       kerja gak sih gabisa ngasih solusi ga customer care
# 22                                                                                                                                  jaring 4g sih lot banget
# 23                                                                                                                xl daerah kp cadas kec legok kab tangerang
# 24                                                                             isi paket 10gb diskon 40 pulsa tarik kuota ga masuk gimana nomor 081908294489
# 25                                                                                                                                              tlg balas dm
# 26                                                                                       jaring internet xl yah udah 4g lte lot banget kalah 3g telkomsel cc
# 27                                                                                                                            xl malem buka aplikasi apa lot
# 28                                                                                                                        internet by indihome dipake ku 6an
# 29                                                                             isi paket 10gb diskon 40 pulsa tarik kuota ga masuk gimana nomor 081908294489
# 30                                                                                                        misi atulah xl jelek banget koneksi ngga load gitu
# 31                                                                                  ganti paket xtra combo paket hotrod ubah liat twitter kayakk gin gin aja
# 32                                                                                                             ngapa si dr siang koneksi internet ancur gjni
# 33                                                                                     lapor jaring daerah sungai ulin banjarbaru kalsel ganggu sore makasih
# 34                                                                                                                                            cek dm makasih
# 35                                                                                                                              henti langgan xl prio gimana
# 36  halo selamat sore registrasi no kak sesuai instruksi memaksukan daftar nik kk kirim 4444 kendala ni kak liat foto yaa kak tolong fast respon terimakasih
# 37                                                                                                     gamau beli kuota aplikasi myxl diskon zonk huuuuuuuuu
# 38                                                                                                                               banget muncul ganggu banget
# 39                                                                           sy mw dftar kartu xl tulisanya kartu mmenuhi kuota pdhl sya blm prnh dftar pake
# 40                                                                                                 gimana sih kuota bejibun kena pakai kb kayak indosat plis
# 41                                                                                                     sebel diskon 17k ngga sia sia beli pulsa 100k akuuuuu
# 42                                                                                                             parah ni paket data udah 4g xl bekas timur cc
# 43                                                                                                                               selamat sore no gak tlp sms
# 44                                                                                                                                                    bca dm
# 45                                                          johanfjr ularb0yz myxlcare 2 lapor sila kirim sms format tipu sms tipu kirim nomor 1166 tks endo
#
#                                                                                                                                                   clean_text
# 0                                                               jam 19 34 sampe sinyal ilang lokasi dusun reng desa sendangsari asih kulon progo wates jogja
# 1                                          hi roleplayer mohon maaf tingkat kualitas jaring lokasi kait tangan usaha selesai alas 4 bln komplain eoql sinyal
# 2                                                                          msh langgan paket internet beli paket haji langgan paket internet msh laku hangus
# 3                                                                                   koneksi bikin emosi jujur kualitas lbh bagus gabung jaring miss that day
# 4                                                                                                                                     xl center bintaro mana
# 5                                                                                                               jaring coba telp nomor nyambung terima kasih
# 6                                                                                                          xl daerah batu ceper sinyal 3g ga 4g ganggu sampe
# 7                                                                                tnya kouta sisa 6gb tdak pake internetan kartu kendala ngestack 6gb ga inet
# 8                                                                                                                                              bye alih tsel
# 9                                                                                                               sinyal jelek ngirim wa aja pending sinyal 3g
# 10                                                                                                                                          guys dinotice xl
# 11                                               kenapasiiii xl hembel bangetttt youtube gabisa soundcloud gabisa browsing sya suruh hening cipta aja maksud
# 12                                                           xl kemarin dri jam 8malam dah signalnya ilang smpe sekarangg pending molooo pdhl udah direstart
# 13                                           haloo kuota 24jam 2g 3g 4g area batas area rugi konsumen sisa kuota sampe 6gb tidak mohon direspect terimakasih
# 14                                          ken maki maki aja jshdsh sih lot banget buka twitter sumpah pake indos t aja ga lot sinyal stabil cepet darimana
# 15                                                                                                                    hp 2 beda provider jaring lot bazengan
# 16                                                                                                                               jaring putus putus gerangan
# 17                                                                                                                         daftar paket xl xtra combo muncul
# 18                                                                           jam gin maintenance sering maintenance ah gabagus kl it gabecus potong gaji aja
# 19                                                                                                                         tlg balas dm admin m17 hhhhhhhhhh
# 20                                                           please stop spamming my phone with your pop up ads ganggu banget loh iklan pop up buka hp iklan
# 21                                                                                                     kerja tidak sih gabisa ngasih solusi ga customer care
# 22                                                                                                                                  jaring 4g sih lot banget
# 23                                                                                                                xl daerah kp cadas kec legok kab tangerang
# 24                                                                             isi paket 10gb diskon 40 pulsa tarik kuota ga masuk gimana nomor 081908294489
# 25                                                                                                                                              tlg balas dm
# 26                                                                                       jaring internet xl yah udah 4g lte lot banget kalah 3g telkomsel cc
# 27                                                                                                                            xl malem buka aplikasi apa lot
# 28                                                                                                                        internet by indihome dipake ku 6an
# 29                                                                             isi paket 10gb diskon 40 pulsa tarik kuota ga masuk gimana nomor 081908294489
# 30                                                                                                        misi atulah xl jelek banget koneksi ngga load gitu
# 31                                                                                  ganti paket xtra combo paket hotrod ubah liat twitter kayakk gin gin aja
# 32                                                                                                             ngapa si dr siang koneksi internet ancur gjni
# 33                                                                                     lapor jaring daerah sungai ulin banjarbaru kalsel ganggu sore makasih
# 34                                                                                                                                            cek dm makasih
# 35                                                                                                                              henti langgan xl prio gimana
# 36  halo selamat sore registrasi no kak sesuai instruksi memaksukan daftar nik kk kirim 4444 kendala ni kak liat foto yaa kak tolong fast respon terimakasih
# 37                                                                                                     gamau beli kuota aplikasi myxl diskon zonk huuuuuuuuu
# 38                                                                                                                               banget muncul ganggu banget
# 39                                                                           sy mw dftar kartu xl tulisanya kartu mmenuhi kuota pdhl sya blm prnh dftar pake
# 40                                                                                                 gimana sih kuota bejibun kena pakai kb kayak indosat plis
# 41                                                                                                     sebel diskon 17k ngga sia sia beli pulsa 100k akuuuuu
# 42                                                                                                             parah ni paket data udah 4g xl bekas timur cc
# 43                                                                                                                             selamat sore no tidak tlp sms
# 44                                                                                                                                                    bca dm
# 45                                                          johanfjr ularb0yz myxlcare 2 lapor sila kirim sms format tipu sms tipu kirim nomor 1166 tks endo

# %%
import csv
testing = data_clean.cleaned_text[:1100]
final_result = []
for t in testing:
    final_result.append(cleaning_text(t))

with open('data/bersih/clear2.csv', 'a') as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in final_result:
        writer.writerow([val])

print("berhasil disimpan cuuyyyyy")
# Out:
# berhasil disimpan cuuyyyyy
